# %%
# data from http://archive.ics.uci.edu/ml/datasets/SUSY#

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
SUSY_data = pd.read_csv('SUSY.csv')

# %%
labels = ["class","lep1 pT", "lep1 eta", "lep1 phi", "lep2 pT", "lep2 eta", "lep2 phi", "MEmag", "ME phi", "MET_rel", "axial MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos(theta_r1)"]
SUSY_data.columns = labels

# %%
SUSY_data.head()
# Out:
#    class   lep1 pT  lep1 eta  lep1 phi   lep2 pT  lep2 eta  lep2 phi  \
# 0    1.0  1.667973  0.064191 -1.225171  0.506102 -0.338939  1.672543
# 1    1.0  0.444840 -0.134298 -0.709972  0.451719 -1.613871 -0.768661
# 2    1.0  0.381256 -0.976145  0.693152  0.448959  0.891753 -0.677328
# 3    1.0  1.309996 -0.690089 -0.676259  1.589283 -0.693326  0.622907
# 4    0.0  0.456398  1.099371  1.512453  0.751772  0.638967 -0.742216
#
#       MEmag    ME phi   MET_rel  axial MET       M_R    M_TR_2         R  \
# 0  3.475464 -1.219136  0.012955   3.775174  1.045977  0.568051  0.481928
# 1  1.219918  0.504026  1.831248  -0.431385  0.526283  0.941514  1.587535
# 2  2.033060  1.533041  3.046260  -1.005285  0.569386  1.015211  1.582217
# 3  1.087562 -0.381742  0.589204   1.365479  1.179295  0.968218  0.728563
# 4  0.322601  1.321054  0.169502   0.359941  0.489256  0.416168  0.754829
#
#         MT2       S_R  M_Delta_R  dPhi_r_b  cos(theta_r1)
# ...

# %%
dfSignal = SUSY_data[SUSY_data["class"] == 1]
dfbackg = SUSY_data[SUSY_data["class"] == 0]

# %%
x = SUSY_data["MEmag"]
y = SUSY_data["MT2"]

plt.scatter(x,y)
plt.show()

# %%
bin_list = [ + 4*i/60  for i in range(60)]
dfSignal["lep1 pT"].hist(bins=bin_list, label = "Signal")
dfbackg["lep1 pT"].hist(bins=bin_list,label= "Background")

legend = plt.legend(loc='upper right', shadow=True, fontsize='large') #Calling the Legend

# %%
bin_list = [ + 4*i/60  for i in range(60)]
dfSignal["lep2 pT"].hist(bins=bin_list, label = "Signal")
dfbackg["lep2 pT"].hist(bins=bin_list,label= "Background")

legend = plt.legend(loc='upper right', shadow=True, fontsize='large') #Calling the Legend

# %%
bin_list = [ -1.8 + i/15  for i in range(60)]
dfSignal["lep1 phi"].hist(bins=bin_list, label = "Signal")
dfbackg["lep1 phi"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [ -1.8 + i/15  for i in range(60)]
dfSignal["lep2 phi"].hist(bins=bin_list, label = "Signal")
dfbackg["lep2 phi"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [-2.5 + 4*i/45  for i in range(60)]
dfSignal["lep1 eta"].hist(bins=bin_list, label = "Signal")
dfbackg["lep1 eta"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [-2.5 + 4*i/45  for i in range(60)]
dfSignal["lep2 eta"].hist(bins=bin_list, label = "Signal")
dfbackg["lep2 eta"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [ + i/10  for i in range(60)]
dfSignal["MEmag"].hist(bins=bin_list, label = "Signal")
dfbackg["MEmag"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [-2 + i/15  for i in range(60)]
dfSignal["ME phi"].hist(bins=bin_list, label = "Signal")
dfbackg["ME phi"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [ + i/5  for i in range(60)]
dfSignal["MET_rel"].hist(bins=bin_list, label = "Signal")
dfbackg["MET_rel"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [-1 + i/5  for i in range(60)]
dfSignal["axial MET"].hist(bins=bin_list, label = "Signal")
dfbackg["axial MET"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [+ i/5  for i in range(60)]
dfSignal["M_R"].hist(bins=bin_list, label = "Signal")
dfbackg["M_R"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [+ i/5  for i in range(60)]
dfSignal["M_TR_2"].hist(bins=bin_list, label = "Signal")
dfbackg["M_TR_2"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [ i/5  for i in range(60)]
dfSignal["R"].hist(bins=bin_list, label = "Signal")
dfbackg["R"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [+ i/5  for i in range(60)]
dfSignal["MT2"].hist(bins=bin_list, label = "Signal")
dfbackg["MT2"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [ i/5  for i in range(60)]
dfSignal["S_R"].hist(bins=bin_list, label = "Signal")
dfbackg["S_R"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [ i/5  for i in range(60)]
dfSignal["M_Delta_R"].hist(bins=bin_list, label = "Signal")
dfbackg["M_Delta_R"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [-0.2 + 2*i/60  for i in range(60)]
dfSignal["dPhi_r_b"].hist(bins=bin_list, label = "Signal")
dfbackg["dPhi_r_b"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
bin_list = [-0.2 + 2*i/60  for i in range(60)]
dfSignal["cos(theta_r1)"].hist(bins=bin_list, label = "Signal")
dfbackg["cos(theta_r1)"].hist(bins=bin_list,label= "Background")
legend = plt.legend(loc='upper right', shadow=True, fontsize='large')

# %%
xs = dfSignal["MEmag"]
ys = dfSignal["MT2"]

xb = dfbackg["MEmag"]
yb = dfbackg["MT2"]

plt.scatter(xs, ys, marker='^', c="b",label="Signal")
plt.scatter(xb, yb, marker='o', c="r",label = "Background")

plt.legend()
plt.show()

# %%
xs = dfSignal["M_TR_2"]
ys = dfSignal["axial MET"]

xb = dfbackg["M_TR_2"]
yb = dfbackg["axial MET"]

plt.scatter(xs, ys, marker='^', c="b",label="Signal")
plt.scatter(xb, yb, marker='o', c="r",label = "Background")

plt.legend()
plt.show()
